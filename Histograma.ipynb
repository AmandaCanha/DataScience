# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
#Renderizar a plotagem
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 400 #figura de alta resolução

# %%
df = pd.read_excel('C:/Users/User/Documents/MunicipiosBrasil.xlsx')

# %%
df.shape
# Out:
# (5509, 7)

# %%
df.head()
# Out:
#    ID  LATITUDE  LONGITUDE             Mun/UF     MUNICIPIO  UF  \
# 0   1     -9.82     -66.88    ACRELANDIA - AC    ACRELANDIA  AC
# 1   2    -10.94     -69.56  ASSIS BRASIL - AC  ASSIS BRASIL  AC
# 2   3    -11.01     -68.74     BRASILEIA - AC     BRASILEIA  AC
# 3   4     -9.83     -67.95        BUJARI - AC        BUJARI  AC
# 4   5    -10.57     -67.67      CAPIXABA - AC      CAPIXABA  AC
#
#              Valor
# 0  395600389105082
# 1  178421509888388
# 2  933733943132296
# 3    2851656749286
# 4  188864551361044

# %%
filtro = df[df['LATITUDE'] < -5]

filtro['UF'].hist(ec = "k", alpha=.6)
# Out:
# <Axes: >
